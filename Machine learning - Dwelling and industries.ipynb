# %% [markdown]
# # Machine learning linearRegression- Dwelling and industries

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv('machinedata.csv')

# %%
data.head(3)
# Out:
#    census_year clue_small_area  accommodation_and_food_services  \
# 0         2002         Carlton                              190
# 1         2002       Docklands                               23
# 2         2002  East Melbourne                               54
#
#    administrative_and_support_services  agriculture_forestry_and_fishing  \
# 0                                   40                                 0
# 1                                    6                                 1
# 2                                   22                                 0
#
#    arts_and_recreation_services  construction  education_and_training  \
# 0                            31            13                      61
# 1                             9             4                       1
# 2                            42             4                      12
#
#    electricity_gas_water_and_waste_services  financial_and_insurance_services  \
# ...

# %%
# Encoding 'clue_small_area'
le = preprocessing.LabelEncoder()
data['clue_small_area'] = le.fit_transform(data['clue_small_area'].values)

# %%
data.head(3)
# Out:
#    census_year  clue_small_area  accommodation_and_food_services  \
# 0         2002                0                              190
# 1         2002                1                               23
# 2         2002                2                               54
#
#    administrative_and_support_services  agriculture_forestry_and_fishing  \
# 0                                   40                                 0
# 1                                    6                                 1
# 2                                   22                                 0
#
#    arts_and_recreation_services  construction  education_and_training  \
# 0                            31            13                      61
# 1                             9             4                       1
# 2                            42             4                      12
#
#    electricity_gas_water_and_waste_services  financial_and_insurance_services  \
# ...

# %%
data.describe()
# Out:
#        census_year  clue_small_area  accommodation_and_food_services  \
# count   273.000000       273.000000                       273.000000
# mean   2012.000000         6.000000                       195.161172
# std       6.066422         3.748529                       412.858066
# min    2002.000000         0.000000                         1.000000
# 25%    2007.000000         3.000000                        24.000000
# 50%    2012.000000         6.000000                        58.000000
# 75%    2017.000000         9.000000                       148.000000
# max    2022.000000        12.000000                      2491.000000
#
#        administrative_and_support_services  agriculture_forestry_and_fishing  \
# count                           273.000000                        273.000000
# mean                             51.721612                          1.252747
# std                             127.443425                          1.878243
# ...

# %%
# All the values are going to be scaled except for target value
warnings.filterwarnings('ignore')
scaler = StandardScaler()
data.iloc[:,2:-2] = scaler.fit_transform(data.iloc[:,2:-2])

# %%
data.describe()
# Out:
#        census_year  clue_small_area  accommodation_and_food_services  \
# count   273.000000       273.000000                     2.730000e+02
# mean   2012.000000         6.000000                     2.602721e-17
# std       6.066422         3.748529                     1.001837e+00
# min    2002.000000         0.000000                    -4.711492e-01
# 25%    2007.000000         3.000000                    -4.153377e-01
# 50%    2012.000000         6.000000                    -3.328337e-01
# 75%    2017.000000         9.000000                    -1.144407e-01
# max    2022.000000        12.000000                     5.571056e+00
#
#        administrative_and_support_services  agriculture_forestry_and_fishing  \
# count                         2.730000e+02                      2.730000e+02
# mean                         -1.301360e-17                     -6.506802e-18
# std                           1.001837e+00                      1.001837e+00
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(data.iloc[:,:-2], data.iloc[:,-1], test_size=0.40, random_state=42)

# %%
# creating model
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
import warnings
y_pred = model.predict(X_test)

# %%
print(model.coef_)
# Out:
# [-2.06787029e+00 -1.21247063e+01  4.41567375e+03  3.18219834e+03
#   2.04232986e+02 -2.67484776e+02  7.34752855e+02 -8.12550569e+02
#   2.29398393e+02 -2.34222155e+02  1.83440685e+02 -5.33151112e+02
#  -1.02883153e+03 -1.24348916e+02 -4.99132668e+02 -4.91093610e+02
#  -2.39643215e+03 -5.88533260e+02 -1.32212419e+03 -4.60038643e+01
#   2.44166689e+01]

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import median_absolute_error
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from sklearn.linear_model import LogisticRegression

# %%
def linear_model(X_train, X_test, y_train, y_test):
    model = LinearRegression()
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    warnings.filterwarnings('ignore')
    s = model.score(X_test,y_test)
    r = r2_score(y_test,y_pred)
    m = median_absolute_error(y_test, y_pred)
    print("Performance of Linear model")
    print(f"Model score: {s.round(2)}")
    print(f"The r2_score: {r.round(2)}")
    print(f"The mean absolute error: {m.round(2)}")

# %%
linear_model(X_train, X_test, y_train, y_test)
# Out:
# Performance of Linear model
# Model score: 0.47
# The r2_score: 0.47
# The mean absolute error: 301.36

# %%
def logistic_model(X_train, X_test, y_train, y_test, penalty, solver):
    model2 = LogisticRegression(penalty =penalty,solver =solver)
    model2.fit(X_train, y_train)
    y_pred = model2.predict(X_test)
    s = model2.score(X_test,y_test)
    r = r2_score(y_test,y_pred)
    m = median_absolute_error(y_test, y_pred)
    print("Performance of Logistic Regression")
    print(f"Penalty: {penalty}, solver: {solver}")
    print(f"Model score: {s.round(2)}")
    print(f"The r2_score: {r.round(2)}")
    print(f"The mean absolute error: {m.round(2)}")
    return r

# %%
#testing logistic model
r1 = logistic_model(X_train, X_test, y_train, y_test, 'none', 'lbfgs')
# Out:
# Performance of Logistic Regression
# Penalty: none, solver: lbfgs
# Model score: 0.33
# The r2_score: 0.51
# The mean absolute error: 91.5

# %%
r2 = logistic_model(X_train, X_test, y_train, y_test, 'l2', 'lbfgs')
# Out:
# Performance of Logistic Regression
# Penalty: l2, solver: lbfgs
# Model score: 0.33
# The r2_score: 0.52
# The mean absolute error: 76.0

# %%
r3 = logistic_model(X_train, X_test, y_train, y_test, 'l1', 'liblinear')
# Out:
# Performance of Logistic Regression
# Penalty: l1, solver: liblinear
# Model score: 0.34
# The r2_score: 0.12
# The mean absolute error: 88.0

# %%
r4 = logistic_model(X_train, X_test, y_train, y_test, 'l2', 'liblinear')
# Out:
# Performance of Logistic Regression
# Penalty: l2, solver: liblinear
# Model score: 0.33
# The r2_score: 0.54
# The mean absolute error: 88.0

# %%
r4 = logistic_model(X_train, X_test, y_train, y_test, 'l2', 'newton-cholesky')
# Out:
# Performance of Logistic Regression
# Penalty: l2, solver: newton-cholesky
# Model score: 0.33
# The r2_score: 0.54
# The mean absolute error: 83.5

# %% [markdown]
# ## Regression with decision trees

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
def tree_model(X_train, X_test, y_train, y_test, random, max_depth):
    model = DecisionTreeRegressor(random_state = random,max_depth =max_depth)
    model.fit(X_train, y_train)
    
    y_pred = model.predict(X_test)
    s = model.score(X_test,y_test)
    return s.round(2)

# %%
tree_model(X_train, X_test, y_train, y_test, 10,10)
# Out:
# 0.45

# %%
score_3 =[]
for i in range(0,20):
    s =tree_model(X_train, X_test, y_train, y_test, i, 3)
    score_3.append(s)

# %%
print(max(score_3))
# Out:
# 0.61

# %%
plt.plot(score_3)

# %%
score_4 =[]
for i in range(0,20):
    s =tree_model(X_train, X_test, y_train, y_test, i, 4)
    score_4.append(s)
print(max(score_4))
plt.plot(score_4)
# Out:
# 0.57

# %%
score_6 =[]
for i in range(0,20):
    s =tree_model(X_train, X_test, y_train, y_test, i, 6)
    score_6.append(s)
print(max(score_6))
plt.plot(score_6)
# Out:
# 0.48

# %% [markdown]
# ## Support vector regression

# %%
from sklearn.svm import SVR

# %%
def svr_model(X_train, X_test, y_train, y_test, kernel, C ):
    model = SVR(kernel = kernel, C=C)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    s = model.score(X_test,y_test)
    return s.round(2)

# %%
score = svr_model(X_train, X_test, y_train, y_test, 'poly',10.0)
print(score)
# Out:
# -0.14

# %%
score = svr_model(X_train, X_test, y_train, y_test, 'poly',1.0)
print(score)
# Out:
# -0.14

# %%
score = svr_model(X_train, X_test, y_train, y_test, 'linear',10.0)
print(score)
# Out:
# 0.32

# %%
score1=[]
for i in range(1,100):
    i= float(i)
    s =svr_model(X_train, X_test, y_train, y_test, 'linear',i)
    score1.append(s)
print(max(score1))
plt.plot(score1)
# Out:
# 0.47

# %% [markdown]
# # Form the above, the data is not correlating. Further work is required.

# %%
dataF = data.copy()
dataF.head(2)
# Out:
#    census_year  clue_small_area  accommodation_and_food_services  \
# 0         2002                0                        -0.012524
# 1         2002                1                        -0.417764
#
#    administrative_and_support_services  agriculture_forestry_and_fishing  \
# 0                            -0.092144                         -0.668203
# 1                            -0.359419                         -0.134813
#
#    arts_and_recreation_services  construction  education_and_training  \
# 0                     -0.293772     -0.295950                0.275192
# 1                     -0.837835     -0.615296               -0.495873
#
#    electricity_gas_water_and_waste_services  financial_and_insurance_services  \
# 0                                 -0.090556                         -0.150633
# 1                                 -0.540043                         -0.361412
#
#    ...    mining  other_services  \
# 0  ... -0.338708        0.165559
# ...

# %%
dataF.iloc[:,2:]= scaler.fit_transform(dataF.iloc[:,2:])

# %%
sns.heatmap(dataF.loc[dataF['clue_small_area']==0,:].iloc[:,2:].corr().round(1),vmin=-1,vmax=1, annot=True, cmap='BrBG', fmt=".0f", linewidths=.4)
plt.show()

# %%
sns.heatmap(dataF.loc[dataF['clue_small_area']==1,:].iloc[:,2:].corr().round(1),vmin=-1,vmax=1, annot=True, cmap='BrBG', fmt=".0f", linewidths=.5)
plt.show()

# %%
sns.heatmap(dataF.loc[dataF['clue_small_area']==3,:].iloc[:,2:].corr().round(1),vmin=-1,vmax=1,annot=True, cmap='BrBG', fmt=".0f", linewidths=.5)
plt.show()

# %%
sns.heatmap(dataF.loc[dataF['clue_small_area']==4,:].iloc[:,2:].corr().round(1),vmin=-1,vmax=1, annot=True, cmap='BrBG', fmt=".0f", linewidths=.5)
plt.show()

# %%
sns.heatmap(dataF.loc[dataF['clue_small_area']==5,:].iloc[:,2:].corr().round(1),vmin=-1,vmax=1, annot=True, cmap='BrBG', fmt=".0f", linewidths=.5)
plt.show()

# %%
sns.heatmap(dataF.loc[dataF['clue_small_area']==6,:].iloc[:,2:].corr().round(1),vmin=-1,vmax=1, annot=True, cmap='BrBG', fmt=".0f", linewidths=.5)
plt.show()

# %%
sns.heatmap(dataF.loc[dataF['clue_small_area']==7,:].iloc[:,2:].corr().round(1),vmin=-1,vmax=1, annot=True, cmap='BrBG', fmt=".0f", linewidths=.5)
plt.show()

# %%
sns.heatmap(dataF.loc[dataF['clue_small_area']==8,:].iloc[:,2:].corr().round(1),vmin=-1,vmax=1, annot=True, cmap='BrBG', fmt=".0f", linewidths=.5)
plt.show()

# %%
sns.heatmap(dataF.loc[dataF['clue_small_area']==9,:].iloc[:,2:].corr().round(1),vmin=-1,vmax=1, annot=True, cmap='BrBG', fmt=".0f", linewidths=.5)
plt.show()

# %%
sns.heatmap(dataF.loc[dataF['clue_small_area']==10,:].iloc[:,2:].corr().round(1),vmin=-1,vmax=1, annot=True, cmap='BrBG', fmt=".0f", linewidths=.5)
plt.show()
